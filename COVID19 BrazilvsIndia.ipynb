# %% [markdown]
# <a href="https://colab.research.google.com/github/hariniramanan/Machine-Learning-Projects/blob/main/COVID19%20BrazilvsIndia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
print(numpy.__version__)
# Out:
# 2.0.2

# %%
import os
if not os.path.exists('/content/COVIPRED-INDIAN'):
    # !git clone https://github.com/debashreebanerjee/COVIPRED-INDIAN.git
# %cd /content/COVIPRED-INDIAN/Codes
# !pip install -q shap
# Out:
# /content/COVIPRED-INDIAN/Codes

# %%
import numpy, pandas, sklearn, xgboost, imblearn, joblib, matplotlib, seaborn, shap, os
for m in [numpy, pandas, sklearn, xgboost, imblearn, joblib, matplotlib, seaborn, shap]:
    print(f'{m.__name__:14} {m.__version__}')
print('cwd:', os.getcwd())
print('data found:', os.path.exists('../Data/3-fourteen-feature.csv'))
print('model found:', os.path.exists('../Models/brazil_model.pkl'))
# Out:
# numpy          2.0.2
# pandas         2.2.2
# sklearn        1.6.1
# xgboost        3.3.0
# imblearn       0.14.2
# joblib         1.5.3
# matplotlib     3.10.0
# seaborn        0.13.2
# shap           0.52.0
# cwd: /content/COVIPRED-INDIAN/Codes
# data found: True
# model found: True

# %%
from xgboost import XGBClassifier
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, balanced_accuracy_score, fbeta_score, brier_score_loss, recall_score
import pickle as pkl
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
def avgKS(df1, df2):
  '''Calculates the average Kolmogorov-Smirnov statistic between two dataframes.
  Utilized for EPD generation.
  Args:
    df1 (pd.Dataframe): First dataframe.
    df2 (pd.Dataframe): Second dataframe.
  Returns:
    float: Average Kolmogorov-Smirnov statistic.'''
  ksstats = []
  cols = (df1.columns)
  for col in cols:
    cdf1 = (df1[col].sort_values().cumsum())/(len(df1))
    cdf2 = (df2[col].sort_values().cumsum())/(len(df2))
    ksstats.append(np.max(np.abs(cdf1 - cdf2)))
  return np.average(ksstats)

# %%
df1 = pd.read_csv('../Data/Edited_bitsM.csv')
df2 = pd.read_csv('../Data/ESIdf.csv')

# %%
df1
# Out:
#      Unnamed: 0  Gender   Age  Haemoglobin(gms%)  Total WBC Count(/Cumm)  \
# 0             0    Male  63.0               11.6                   10200
# 1             1  Female  27.0               13.7                    7100
# 2             2    Male  63.0               11.1                    8500
# 3             3    Male  35.0               14.0                    5500
# 4             4    Male  19.0               13.2                    5100
# ..          ...     ...   ...                ...                     ...
# 331         331    Male  37.0               14.7                    7600
# 332         332    Male  49.0               13.7                    8000
# 333         333    Male  49.0               14.7                    7000
# 334         334    Male  34.0               14.4                    7000
# 335         335    Male  13.0               14.8                    5000
#
#      Neutrophils(%)  Lymphocytes(%)  Eosinophils(%)  Monocytes(%)  \
# 0                72              23               2             3
# 1                63              34               1             2
# 2                59              35               3             3
# 3                45              50               2             3
# 4                61              33               3             3
# ..              ...             ...             ...           ...
# 331              68              21               4             7
# 332              68              18               5             9
# 333              70              21               3             6
# 334              68              25               3             4
# 335              47              37               4            10
#
#      Basophils(%)  Others  Total RBC Count(millions/Cu)  HCT(%)  MCV(f L)  \
# 0               0       0                          4.20    35.0      84.0
# 1               0       0                          4.36    40.1      92.0
# 2               0       0                          4.00    33.5      84.0
# 3               0       0                          4.73    42.0      89.0
# 4               0       0                          3.27    42.2      80.0
# ..            ...     ...                           ...     ...       ...
# 331             0       0                          5.06    42.1      83.2
# 332             0       0                          4.79    41.0      85.6
# 333             0       0                          5.15    44.0      85.4
# 334             0       0                          4.63    41.2      89.0
# 335             0       0                          5.64    44.3      78.5
#
#      MCH(pg)  MCHC(gms%)  RDWCV(%)  Platelet Count(Lakh / Cumm)    Result
# 0       28.3        33.7      14.4                         2.20  Negative
# 1       31.3        34.1      14.1                         2.48  Negative
# 2       27.9        33.3      14.0                         2.68  Negative
# 3       29.7        33.4      14.3                         2.34  Negative
# 4       25.1        31.4      15.4                         1.94  Negative
# ..       ...         ...       ...                          ...       ...
# 331     29.1        34.9      12.8                         2.11  Positive
# 332     28.6        33.4      12.7                         2.43  Positive
# 333     28.5        33.4      12.8                         2.04  Positive
# 334     31.1        35.0      12.7                         1.47  Positive
# 335     26.2        33.4      13.6                         2.18  Positive
#
# [336 rows x 19 columns]

# %%
#using only 300 negatives, fill with that average
df1 = df1[df1['Result'] != 'Positive']

# %%
df = pd.concat([df1, df2], join = 'inner')

# %%
df.shape
# Out:
# (375, 19)

# %%
encoder = LabelEncoder()
df.drop(columns = [df.columns[0], 'Others'], inplace = True) #Dropping the 'unnamed' column and 'others' column
df['Result'] = encoder.fit_transform(df['Result'])  #Output -> negative = 0, positive = 1
df['Gender'] = encoder.fit_transform(df['Gender']) #Output -> Female = 0, Male = 1

# %%
df
# Out:
#     Gender   Age  Haemoglobin(gms%)  Total WBC Count(/Cumm)  Neutrophils(%)  \
# 0        1  63.0               11.6                   10200              72
# 1        0  27.0               13.7                    7100              63
# 2        1  63.0               11.1                    8500              59
# 3        1  35.0               14.0                    5500              45
# 4        1  19.0               13.2                    5100              61
# ..     ...   ...                ...                     ...             ...
# 70       1  71.0               14.0                    9100              91
# 71       0  72.0               10.2                   11880              81
# 72       1  73.0               12.4                   21110              91
# 73       0  75.0               11.3                    8400              63
# 74       1  82.0               14.4                    6300              73
#
#     Lymphocytes(%)  Eosinophils(%)  Monocytes(%)  Basophils(%)  \
# 0               23               2             3             0
# 1               34               1             2             0
# 2               35               3             3             0
# 3               50               2             3             0
# 4               33               3             3             0
# ..             ...             ...           ...           ...
# 70               6               0             1             0
# 71              13               0             3             0
# 72               6               0             1             0
# 73              31               2             3             0
# 74              18               0             7             0
#
#     Total RBC Count(millions/Cu)  HCT(%)  MCV(f L)  MCH(pg)  MCHC(gms%)  \
# 0                           4.20    35.0      84.0     28.3        33.7
# 1                           4.36    40.1      92.0     31.3        34.1
# 2                           4.00    33.5      84.0     27.9        33.3
# 3                           4.73    42.0      89.0     29.7        33.4
# 4                           3.27    42.2      80.0     25.1        31.4
# ..                           ...     ...       ...      ...         ...
# 70                          5.20    39.3      75.0     26.7        35.6
# 71                          3.40    29.7      85.3     29.3        34.3
# 72                          4.20    35.8      84.8     29.4        34.6
# 73                          3.90    34.0      87.0     28.9        33.2
# 74                          4.90    43.0      86.9     29.1        33.5
#
#     RDWCV(%)  Platelet Count(Lakh / Cumm)  Result
# 0       14.4                         2.20       0
# 1       14.1                         2.48       0
# 2       14.0                         2.68       0
# 3       14.3                         2.34       0
# 4       15.4                         1.94       0
# ..       ...                          ...     ...
# 70      15.6                         1.70       1
# 71      12.1                         6.00       1
# 72      14.6                         2.40       1
# 73      13.6                         3.80       1
# 74      14.2                         1.60       1
#
# [375 rows x 17 columns]

# %%
# Defining the columns in a particular order
order = ['HCT(%)', 'Haemoglobin(gms%)', 'Platelet Count(Lakh / Cumm)', 'Total RBC Count(millions/Cu)',
         'Lymphocytes(%)', 'MCHC(gms%)', 'Total WBC Count(/Cumm)', 'Basophils(%)', 'MCH(pg)',
         'Eosinophils(%)', 'MCV(f L)', 'Monocytes(%)', 'Result']

# Rearranging the columns in the defined order
df = df[order]

# Standardizing the data (z-score normalization, mean = 0, std = 1).
cols = df.columns.tolist()
cols.remove('Result') # Removing the target variable from the list of columns to be standardized

for c in cols: #standardizing the data
    df[c] = ((df[c] - (df[c].mean())))/(df[c].std())

X_test = df.drop(columns = ['Result']) #Indian dataset as test set
Y_test = df['Result']

# %%
df
# Out:
#       HCT(%)  Haemoglobin(gms%)  Platelet Count(Lakh / Cumm)  \
# 0  -0.513971          -0.480113                    -0.331979
# 1   0.379070           0.524642                    -0.032256
# 2  -0.776630          -0.719341                     0.181832
# 3   0.711771           0.668178                    -0.182117
# 4   0.746792           0.285414                    -0.610293
# ..       ...                ...                          ...
# 70  0.238985           0.668178                    -0.867198
# 71 -1.442033          -1.149950                     3.735689
# 72 -0.373886          -0.097350                    -0.117891
# 73 -0.689077          -0.623650                     1.380723
# 74  0.886877           0.859560                    -0.974242
#
#     Total RBC Count(millions/Cu)  Lymphocytes(%)  MCHC(gms%)  \
# 0                      -0.239918       -0.492923    0.327976
# 1                       0.010453        0.421334    0.514256
# 2                      -0.552883        0.504449    0.141697
# 3                       0.589437        1.751163    0.188266
# 4                      -1.695202        0.338220   -0.743131
# ..                           ...             ...         ...
# 70                      1.324903       -1.905867    1.212804
# 71                     -1.491775       -1.324067    0.607395
# 72                     -0.239918       -1.905867    0.747105
# 73                     -0.709365        0.171991    0.095127
# 74                      0.855456       -0.908495    0.234836
#
#     Total WBC Count(/Cumm)  Basophils(%)   MCH(pg)  Eosinophils(%)  MCV(f L)  \
# 0                 0.574967      -0.05164  0.134979       -0.173565  0.013915
# 1                -0.313472      -0.05164  1.037244       -0.744503  1.012611
# 2                 0.087759      -0.05164  0.014677        0.397373  0.013915
# 3                -0.772021      -0.05164  0.556036       -0.173565  0.638100
# 4                -0.886659      -0.05164 -0.827437        0.397373 -0.485433
# ..                     ...           ...       ...             ...       ...
# 70                0.259715      -0.05164 -0.346229       -1.315441 -1.109618
# 71                1.056444      -0.05164  0.435734       -1.315441  0.176203
# 72                3.701700      -0.05164  0.465809       -1.315441  0.113785
# 73                0.059099      -0.05164  0.315432       -0.173565  0.388426
# 74               -0.542747      -0.05164  0.375583       -1.315441  0.375943
#
#     Monocytes(%)  Result
# 0      -0.363387       0
# 1      -0.919592       0
# 2      -0.363387       0
# 3      -0.363387       0
# 4      -0.363387       0
# ..           ...     ...
# 70     -1.475796       1
# 71     -0.363387       1
# 72     -1.475796       1
# 73     -0.363387       1
# 74      1.861432       1
#
# [375 rows x 13 columns]

# %% [markdown]
# ## Creation of Brazilian model

# %%
dfBrazil = pd.read_csv('../Data/3-fourteen-feature.csv')

# %%
dfBrazil.head()
# Out:
#    Hematocrit  Hemoglobin  Platelets       MPV  Erythrocytes  Lymphocytes  \
# 0   -2.085973   -2.032676  -1.235475  2.317897     -2.145106    -0.328111
# 1   -1.274456   -1.352212   2.319303  0.095416     -1.278015    -0.334471
# 2   -0.304165   -0.137099   0.819447 -0.222081     -0.369634    -0.073713
# 3   -1.045115   -1.011980   2.094915  0.412913     -1.112855    -0.244275
# 4   -0.621715   -0.623144   1.716999  0.518746     -0.741245     0.039610
#
#        MCHC  Leukocytes  Basophils       MCH  Eosinophils       MCV  \
# 0 -0.418941   -0.038206   1.005582  0.625119    -0.558567  0.904244
# 1 -0.854400    0.794473  -0.576866 -0.092740    -0.114376  0.315128
# 2  0.713251   -0.135622   0.028762  0.529404    -0.353556  0.172312
# 3 -0.157666    1.427680  -0.576866  0.337975    -0.558567  0.440092
# 4 -0.157666    2.158303  -0.576866  0.290118     0.109617  0.422240
#
#    Monocytes       RDW  CoV-2  Probability
# 0  -0.640155  2.080230    0.0     0.428487
# 1   0.116525  0.530675    1.0     0.911545
# 2   0.543436  0.316943    0.0     0.173168
# 3   0.535767  0.851272    0.0     0.662734
# 4   1.916198  0.958138    0.0     0.112475

# %%
dfBrazil[dfBrazil['CoV-2'] == 1]
# Out:
#        Hematocrit  Hemoglobin  Platelets       MPV  Erythrocytes  Lymphocytes  \
# 1       -1.274456   -1.352212   2.319303  0.095416     -1.278015    -0.334471
# 5       -0.939265   -1.206399   1.362702  0.730411     -1.222962    -0.786607
# 7        1.160092    1.175224  -1.070137 -0.433746      0.800251    -0.731101
# 10       0.119234   -0.185703  -0.160775  0.412913      0.538747    -0.131531
# 16       0.401501    0.591970  -1.400814  1.047908      0.414877     0.161606
# ...           ...         ...        ...       ...           ...          ...
# 11881    1.618775    1.612665  -1.117376 -0.010416      1.323258     0.206125
# 11883   -1.045115   -0.914771  -1.282715  2.212064     -0.507268    -0.500408
# 11888   -0.286524   -0.477330  -0.833939  1.471237     -0.314581    -0.673862
# 11893   -0.304165   -0.428726  -0.975658 -0.327913     -0.135657    -0.841533
# 11913    0.260368    0.446156  -0.326113  0.095416      0.139610    -0.184145
#
#            MCHC  Leukocytes  Basophils       MCH  Eosinophils       MCV  \
# 1     -0.854400    0.794473  -0.576866 -0.092740    -0.114376  0.315128
# 5     -0.157666    1.984345  -0.576866  0.146546    -0.558567  0.243720
# 7      0.364884   -1.084273  -0.010310  0.625119    -0.326981  0.475796
# 10    -1.289858   -0.764190  -0.381502 -1.528458    -0.558567 -1.059477
# 16     0.974526   -0.889440  -0.225211  0.290118     0.117210 -0.202581
# ...         ...         ...        ...       ...          ...       ...
# 11881  0.364884   -0.499774  -0.225211  0.385832     0.113414  0.208016
# 11883  0.364884   -1.346369  -0.381502 -0.954171    -0.520602 -1.237998
# 11888 -0.941491   -1.107467  -0.381502 -0.379884    -0.106783  0.065200
# 11893 -0.680216   -0.729399  -0.576866 -0.667027    -0.167527 -0.416805
# 11913  0.887434   -0.379163   0.458563  0.577261     0.121007  0.154460
#
#        Monocytes       RDW  CoV-2  Probability
# 1       0.116525  0.530675    1.0     0.911545
# 5       1.762817  0.958138    1.0     0.897204
# 7      -1.044059 -0.698283    1.0     0.906676
# 10     -1.118193  0.530675    1.0     0.954391
# 16     -0.292491 -0.858581    1.0     0.875864
# ...          ...       ...    ...          ...
# 11881  -0.425422 -0.110520    1.0     0.802353
# 11883  -1.266462  0.316943    1.0     0.908100
# 11888  -0.880452 -0.537984    1.0     0.910985
# 11893  -0.496999 -0.644850    1.0     0.819192
# 11913  -0.098208 -0.484551    1.0     0.468455
#
# [3145 rows x 16 columns]

# %%
#Drop MPV, Probability
dfBrazil = dfBrazil.drop(columns = ['MPV', 'Probability'])
dfBrazil
# Out:
#        Hematocrit  Hemoglobin  Platelets  Erythrocytes  Lymphocytes      MCHC  \
# 0       -2.085973   -2.032676  -1.235475     -2.145106    -0.328111 -0.418941
# 1       -1.274456   -1.352212   2.319303     -1.278015    -0.334471 -0.854400
# 2       -0.304165   -0.137099   0.819447     -0.369634    -0.073713  0.713251
# 3       -1.045115   -1.011980   2.094915     -1.112855    -0.244275 -0.157666
# 4       -0.621715   -0.623144   1.716999     -0.741245     0.039610 -0.157666
# ...           ...         ...        ...           ...          ...       ...
# 11911    0.789617    0.591970  -0.196204      0.249717     0.844434 -0.593125
# 11912    0.383859    0.397552  -0.373353      0.222190    -0.540881  0.190701
# 11913    0.260368    0.446156  -0.326113      0.139610    -0.184145  0.887434
# 11914    0.172159    0.591970  -1.070137     -0.576084    -0.152345  1.932534
# 11915    0.895467    0.932202   0.063613     -0.011787    -0.450685  0.364884
#
#        Leukocytes  Basophils       MCH  Eosinophils       MCV  Monocytes  \
# 0       -0.038206   1.005582  0.625119    -0.558567  0.904244  -0.640155
# 1        0.794473  -0.576866 -0.092740    -0.114376  0.315128   0.116525
# 2       -0.135622   0.028762  0.529404    -0.353556  0.172312   0.543436
# 3        1.427680  -0.576866  0.337975    -0.558567  0.440092   0.535767
# 4        2.158303  -0.576866  0.290118     0.109617  0.422240   1.916198
# ...           ...        ...       ...          ...       ...        ...
# 11911    0.439599   0.419490  0.625119     0.291849  1.029209   0.142089
# 11912    0.425682   0.419490  0.290118    -0.137155  0.225868   0.234118
# 11913   -0.379163   0.458563  0.577261     0.121007  0.154460  -0.098208
# 11914    1.796470  -0.576866  2.778695    -0.558567  1.921809  -0.448429
# 11915   -0.205205   0.439027  2.012979    -0.110580  1.957513   1.098165
#
#             RDW  CoV-2
# 0      2.080230    0.0
# 1      0.530675    1.0
# 2      0.316943    0.0
# 3      0.851272    0.0
# 4      0.958138    0.0
# ...         ...    ...
# 11911 -0.377685    0.0
# 11912 -0.965447    0.0
# 11913 -0.484551    1.0
# 11914 -0.751715    0.0
# 11915 -0.003655    0.0
#
# [11916 rows x 14 columns]

# %%
# Renaming columns to match the Indian dataset
dfBrazil = dfBrazil.rename(columns = {'Hematocrit' : 'HCT(%)',
                                      'Hemoglobin' : 'Haemoglobin(gms%)',
                                      'Platelets' : 'Platelet Count(Lakh / Cumm)',
                                      'Erythrocytes' : 'Total RBC Count(millions/Cu)',
                                      'Lymphocytes' : 'Lymphocytes(%)',
                                      'MCHC' : 'MCHC(gms%)',
                                      'Leukocytes' : 'Total WBC Count(/Cumm)',
                                      'Basophils' : 'Basophils(%)',
                                      'MCH' : 'MCH(pg)',
                                      'Eosinophils' : 'Eosinophils(%)',
                                      'MCV' : 'MCV(f L)',
                                      'Monocytes' : 'Monocytes(%)',
                                      'RDW' : 'RDWCV(%)',
                                      'CoV-2' : 'Result'})

# %%
dfBrazil.columns

# Total RBC count is not present in Italian dataset, so we have removed it to maintain consistency
# Out:
# Index(['HCT(%)', 'Haemoglobin(gms%)', 'Platelet Count(Lakh / Cumm)',
#        'Total RBC Count(millions/Cu)', 'Lymphocytes(%)', 'MCHC(gms%)',
#        'Total WBC Count(/Cumm)', 'Basophils(%)', 'MCH(pg)', 'Eosinophils(%)',
#        'MCV(f L)', 'Monocytes(%)', 'RDWCV(%)', 'Result'],
#       dtype='object')

# %%
dfBrazil.drop(columns = ['RDWCV(%)', 'Total RBC Count(millions/Cu)'], inplace=True)

# %%
dfBrazil.head()
# Out:
#      HCT(%)  Haemoglobin(gms%)  Platelet Count(Lakh / Cumm)  Lymphocytes(%)  \
# 0 -2.085973          -2.032676                    -1.235475       -0.328111
# 1 -1.274456          -1.352212                     2.319303       -0.334471
# 2 -0.304165          -0.137099                     0.819447       -0.073713
# 3 -1.045115          -1.011980                     2.094915       -0.244275
# 4 -0.621715          -0.623144                     1.716999        0.039610
#
#    MCHC(gms%)  Total WBC Count(/Cumm)  Basophils(%)   MCH(pg)  Eosinophils(%)  \
# 0   -0.418941               -0.038206      1.005582  0.625119       -0.558567
# 1   -0.854400                0.794473     -0.576866 -0.092740       -0.114376
# 2    0.713251               -0.135622      0.028762  0.529404       -0.353556
# 3   -0.157666                1.427680     -0.576866  0.337975       -0.558567
# 4   -0.157666                2.158303     -0.576866  0.290118        0.109617
#
#    MCV(f L)  Monocytes(%)  Result
# 0  0.904244     -0.640155     0.0
# 1  0.315128      0.116525     1.0
# 2  0.172312      0.543436     0.0
# 3  0.440092      0.535767     0.0
# 4  0.422240      1.916198     0.0

# %%
scores = []

# %%
#Checking for null values
dfBrazil.isnull().sum()

#check null values for each column
for col in dfBrazil.columns:
    print(f"{col} : {dfBrazil[col].isnull().sum()}")
# Out:
# HCT(%) : 0
# Haemoglobin(gms%) : 0
# Platelet Count(Lakh / Cumm) : 0
# Lymphocytes(%) : 0
# MCHC(gms%) : 0
# Total WBC Count(/Cumm) : 0
# Basophils(%) : 0
# MCH(pg) : 0
# Eosinophils(%) : 0
# MCV(f L) : 0
# Monocytes(%) : 0
# Result : 0

# %% [markdown]
# ## Model without splitting

# %%
internal_model = XGBClassifier()
internal_model.fit(dfBrazil.drop(columns = ['Result']), dfBrazil['Result'])
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
##Save the model in a pickle file

#Don't create a new file if one already exists
try:
    with open('../Models/brazil_model.pkl', 'rb') as f:
        internal_model = pkl.load(f)
except FileNotFoundError:
    with open('../Models/brazil_model.pkl', 'wb') as f:
        pkl.dump(internal_model, f)

# %% [markdown]
# ## 375 dataset

# %%
X_test = X_test.drop(columns = ['Total RBC Count(millions/Cu)'] )

# %%
binary_predictions = internal_model.predict(X_test)
accuracy = accuracy_score(Y_test, binary_predictions)
print(f"Accuracy: {accuracy}")
print(classification_report(Y_test, binary_predictions))
cm = confusion_matrix(Y_test, binary_predictions)
sensitivity = cm[1,1]/(cm[1,0]+cm[1,1])
specificity = cm[0,0]/(cm[0,0]+cm[0,1])
balanced_accuracy = balanced_accuracy_score(Y_test, binary_predictions)
f2_score = fbeta_score(Y_test, binary_predictions, beta = 2)
print('sensitivity', sensitivity)
print('specificity', specificity)
print('balanced_accuracy', balanced_accuracy)
print('f2_score', f2_score)
roc_auc = roc_auc_score(Y_test, binary_predictions)
print('roc_auc_score', roc_auc_score(Y_test, binary_predictions))
y_proba = internal_model.predict_proba(X_test)[:, 1]
brier_score = brier_score_loss(Y_test, y_proba)
print('brierscore', brier_score_loss(Y_test, y_proba))
sns.heatmap(cm, annot = True, fmt = "d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

metrics_df = pd.DataFrame({
    'Model' : 'Brazil on India 375',
    'Sensitivity': [sensitivity],
    'Specificity': [specificity],
    'Accuracy' : [accuracy],
    'Balanced Accuracy': [balanced_accuracy],
    'F2 Score': [f2_score],
    'ROC AUC': [roc_auc],
    'Brier Score': [brier_score]
})
display(metrics_df)
# Out:
# Accuracy: 0.7066666666666667
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       300
#            1       0.19      0.15      0.17        75
#
#     accuracy                           0.71       375
#    macro avg       0.50      0.50      0.49       375
# weighted avg       0.68      0.71      0.69       375
#
# sensitivity 0.14666666666666667
# specificity 0.8466666666666667
# balanced_accuracy 0.4966666666666667
# f2_score 0.15406162464985995
# roc_auc_score 0.4966666666666667
# brierscore 0.20504474862109934
#                  Model  Sensitivity  Specificity  Accuracy  Balanced Accuracy  \
# 0  Brazil on India 375     0.146667     0.846667  0.706667           0.496667
#
#    F2 Score   ROC AUC  Brier Score
# 0  0.154062  0.496667     0.205045

# %%
# Similarity score

sim_score375 = avgKS(X_test, dfBrazil)

# %%
out1 = pd.DataFrame()
out1['y_true'] = Y_test.copy()
out1['y_proba'] = ((internal_model.predict_proba(X_test))[:, 1])
out1.to_csv('../Results/1aIndiaBrazil375.csv', index = False)

# %%
def computemetrics(y_true, y_proba):
    thresh = [0.15, 0.5]
    prop = np.mean(y_true == 1)  # prevalence
    auc = roc_auc_score(y_true, y_proba)
    for th in thresh:
        y_pred = (y_proba >= th).astype(int)
        tpr = recall_score(y_true, y_pred)  # sensitivity
        tnr = recall_score(y_true, y_pred, pos_label=0)  # specificity
        std_net_benefit = ((tpr * prop - (1 - tnr) * (1 - prop) * th / (1 - th)) / prop)
        bal_acc = balanced_accuracy_score(y_true, y_pred)
        print(
            f"Threshold - {th} Standardized Net Benefit - {round(std_net_benefit, 3)}",
            f"AUC Score - {round(auc, 3)}",
            f"Balanced Accuracy - {round(bal_acc, 3)}"
        )

# %%
computemetrics(Y_test, y_proba)
# Out:
# Threshold - 0.15 Standardized Net Benefit - 0.198 AUC Score - 0.547 Balanced Accuracy - 0.532
# Threshold - 0.5 Standardized Net Benefit - -0.467 AUC Score - 0.547 Balanced Accuracy - 0.497

# %% [markdown]
# ## Smote Indian Dataset (600)

# %%
df = pd.read_csv('../Data/smoteesimedc.csv')

# %%
df.drop(columns = [df.columns[0], 'Gender', 'Age'])
# Out:
#      Haemoglobin(gms%)  Total WBC Count(/Cumm)  Neutrophils(%)  \
# 0                 11.6                   10200              72
# 1                 13.7                    7100              63
# 2                 11.1                    8500              59
# 3                 14.0                    5500              45
# 4                 13.2                    5100              61
# ..                 ...                     ...             ...
# 595               12.9                   12577              84
# 596                9.9                   16759              90
# 597               10.5                   14470              77
# 598               11.4                   17961              78
# 599               12.8                   13538              50
#
#      Lymphocytes(%)  Eosinophils(%)  Monocytes(%)  Basophils(%)  \
# 0                23               2             3             0
# 1                34               1             2             0
# 2                35               3             3             0
# 3                50               2             3             0
# 4                33               3             3             0
# ..              ...             ...           ...           ...
# 595              12               0             2             0
# 596               6               0             2             0
# 597              12               1             7             0
# 598              18               0             1             0
# 599              42               0             4             0
#
#      Total RBC Count(millions/Cu)  HCT(%)  MCV(f L)  MCH(pg)  MCHC(gms%)  \
# 0                            4.20   35.00     84.00    28.30       33.70
# 1                            4.36   40.10     92.00    31.30       34.10
# 2                            4.00   33.50     84.00    27.90       33.30
# 3                            4.73   42.00     89.00    29.70       33.40
# 4                            3.27   42.20     80.00    25.10       31.40
# ..                            ...     ...       ...      ...         ...
# 595                          4.38   37.64     84.69    29.01       34.30
# 596                          3.79   30.04     78.92    25.93       32.89
# 597                          3.57   32.81     89.67    28.80       32.10
# 598                          3.72   33.82     91.13    30.10       33.13
# 599                          3.91   38.00     96.18    32.42       33.74
#
#      RDWCV(%)  Platelet Count(Lakh / Cumm)  Result
# 0       14.40                         2.20       0
# 1       14.10                         2.48       0
# 2       14.00                         2.68       0
# 3       14.30                         2.34       0
# 4       15.40                         1.94       0
# ..        ...                          ...     ...
# 595     14.69                         1.11       1
# 596     17.51                         4.53       1
# 597     13.55                         4.04       1
# 598     13.75                         2.48       1
# 599     12.94                         4.47       1
#
# [600 rows x 15 columns]

# %%
order = ['HCT(%)', 'Haemoglobin(gms%)', 'Platelet Count(Lakh / Cumm)', 'Total RBC Count(millions/Cu)', 'Lymphocytes(%)', 'MCHC(gms%)', 'Total WBC Count(/Cumm)', 'Basophils(%)', 'MCH(pg)', 'Eosinophils(%)', 'MCV(f L)', 'Monocytes(%)', 'RDWCV(%)', 'Result']
df = df.reindex(columns=dfBrazil.columns)
# df = df[order]
cols = df.columns.tolist()
cols.remove('Result')
for c in cols:
    df[c] = ((df[c] - (df[c].mean())))/(df[c].std())
X_test = df.drop(columns = ['Result'])
Y_test = df['Result']

# %%
X_test
# Out:
#        HCT(%)  Haemoglobin(gms%)  Platelet Count(Lakh / Cumm)  Lymphocytes(%)  \
# 0   -0.506283          -0.504099                    -0.369887       -0.179127
# 1    0.360824           0.444900                    -0.075519        0.675709
# 2   -0.761314          -0.730052                     0.134743        0.753421
# 3    0.683864           0.580471                    -0.222703        1.919106
# 4    0.717868           0.218948                    -0.643228        0.597996
# ..        ...                ...                          ...             ...
# 595 -0.057427           0.083376                    -1.515818       -1.033963
# 596 -1.349586          -1.272337                     2.079672       -1.500237
# 597 -0.878628          -1.001194                     1.564528       -1.033963
# 598 -0.706907          -0.594480                    -0.075519       -0.567689
# 599  0.003780           0.038186                     2.016593        1.297408
#
#      MCHC(gms%)  Total WBC Count(/Cumm)  Basophils(%)   MCH(pg)  \
# 0      0.213477                0.232943     -0.040825  0.074266
# 1      0.410464               -0.536994     -0.040825  1.032127
# 2      0.016489               -0.189281     -0.040825 -0.053449
# 3      0.065736               -0.934382     -0.040825  0.521268
# 4     -0.919199               -1.033729     -0.040825 -0.947452
# ..          ...                     ...           ...       ...
# 595    0.508957                0.823312     -0.040825  0.300960
# 596   -0.185422                1.861983     -0.040825 -0.682444
# 597   -0.574472                1.293471     -0.040825  0.233910
# 598   -0.067230                2.160520     -0.040825  0.648982
# 599    0.233175                1.061993     -0.040825  1.389728
#
#      Eosinophils(%)  MCV(f L)  Monocytes(%)
# 0          0.170456  0.000298     -0.242034
# 1         -0.356728  1.067662     -0.813769
# 2          0.697640  0.000298     -0.242034
# 3          0.170456  0.667400     -0.242034
# 4          0.697640 -0.533384     -0.242034
# ..              ...       ...           ...
# 595       -0.883912  0.092358     -0.813769
# 596       -0.883912 -0.677478     -0.813769
# 597       -0.356728  0.756792      2.044905
# 598       -0.883912  0.951586     -1.385504
# 599       -0.883912  1.625359      0.329700
#
# [600 rows x 11 columns]

# %%
binary_predictions = internal_model.predict(X_test)
accuracy = accuracy_score(Y_test, binary_predictions)
print(f"Accuracy: {accuracy}")
print(classification_report(Y_test, binary_predictions))
cm = confusion_matrix(Y_test, binary_predictions)
sensitivity = cm[1,1]/(cm[1,0]+cm[1,1])
specificity = cm[0,0]/(cm[0,0]+cm[0,1])
balanced_accuracy = balanced_accuracy_score(Y_test, binary_predictions)
f2_score = fbeta_score(Y_test, binary_predictions, beta = 2)
print('sensitivity', sensitivity)
print('specificity', specificity)
print('balanced_accuracy', balanced_accuracy)
print('f2_score', f2_score)
roc_auc = roc_auc_score(Y_test, binary_predictions)
print('roc_auc_score', roc_auc_score(Y_test, binary_predictions))
y_proba = internal_model.predict_proba(X_test)[:, 1]
brier_score = brier_score_loss(Y_test, y_proba)
print('brierscore', brier_score_loss(Y_test, y_proba))
sns.heatmap(cm, annot = True, fmt = "d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

metrics_df2 = pd.DataFrame({
    'Model' : 'Brazil on India Smote',
    'Sensitivity': [sensitivity],
    'Specificity': [specificity],
    'Accuracy' : [accuracy],
    'Balanced Accuracy': [balanced_accuracy],
    'F2 Score': [f2_score],
    'ROC AUC': [roc_auc],
    'Brier Score': [brier_score]
})
display(metrics_df2)
print(metrics_df.columns)
print(metrics_df2.columns)

metrics_df = pd.concat([metrics_df, metrics_df2])
metrics_df
# Out:
# Accuracy: 0.5183333333333333
#               precision    recall  f1-score   support
#
#            0       0.51      0.86      0.64       300
#            1       0.56      0.18      0.27       300
#
#     accuracy                           0.52       600
#    macro avg       0.53      0.52      0.45       600
# weighted avg       0.53      0.52      0.45       600
#
# sensitivity 0.17666666666666667
# specificity 0.86
# balanced_accuracy 0.5183333333333333
# f2_score 0.20463320463320464
# roc_auc_score 0.5183333333333333
# brierscore 0.3498039713894438
#                    Model  Sensitivity  Specificity  Accuracy  \
# 0  Brazil on India Smote     0.176667         0.86  0.518333
#
#    Balanced Accuracy  F2 Score   ROC AUC  Brier Score
# 0           0.518333  0.204633  0.518333     0.349804
# Index(['Model', 'Sensitivity', 'Specificity', 'Accuracy', 'Balanced Accuracy',
#        'F2 Score', 'ROC AUC', 'Brier Score'],
#       dtype='object')
# Index(['Model', 'Sensitivity', 'Specificity', 'Accuracy', 'Balanced Accuracy',
#        'F2 Score', 'ROC AUC', 'Brier Score'],
#       dtype='object')
#                    Model  Sensitivity  Specificity  Accuracy  \
# 0    Brazil on India 375     0.146667     0.846667  0.706667
# 0  Brazil on India Smote     0.176667     0.860000  0.518333
#
#    Balanced Accuracy  F2 Score   ROC AUC  Brier Score
# 0           0.496667  0.154062  0.496667     0.205045
# 0           0.518333  0.204633  0.518333     0.349804

# %%
sim_score600B = avgKS(df, dfBrazil)

# %%
computemetrics(Y_test, y_proba)
# Out:
# Threshold - 0.15 Standardized Net Benefit - 0.498 AUC Score - 0.59 Balanced Accuracy - 0.588
# Threshold - 0.5 Standardized Net Benefit - 0.037 AUC Score - 0.59 Balanced Accuracy - 0.518

# %%
out2 = pd.DataFrame()
out2['y_true'] = Y_test.copy()
out2['y_proba'] = ((internal_model.predict_proba(X_test))[:, 1])
out2.to_csv('../Data/1bIndiaBrazil600.csv', index = False)

# %% [markdown]
# ## Italy

# %%
dfItaly = pd.read_csv('../Data/Dataset-2a.csv')

# %%
dfItaly.drop(columns = ['Sex', 'Age', 'Calcium', 'Creatine_kinase',
                        'Creatinine', 'Alkaline_phosphatase','Gamma_glutamyltransferase', 'Glucose',
                            	'Aspartate_aminotransferase', 'Alanine_aminotransferase', 'Lactate_dehydrogenase',
                        'Urea', 'Covid-specific_symptoms', 'Erythrocytes_(10^12/L)', 'Neutrophils_(10^9/L)',
                        'Lymphocytes_(10^9/L)',	'Monocytes_(10^9/L)',
                        'Eosinophils_(10^9/L)',	'Basophils_(10^9/L)'], inplace=True)

# %%
# #Preprocessing

dfItaly.rename(columns = {'CoV-2' : 'Result', 'Leukocytes_(10^9/L)' : 'Total WBC Count(/Cumm)',
                          'Platelets_(10^9/L)' : 'Platelet Count(Lakh / Cumm)', 'MCHC' : 'MCHC(gms%)',
                          'Hemoglobin' : 'Haemoglobin(gms%)', 'MCV' : 'MCV(f L)',
                          'Eosinophils_(%)' : 'Eosinophils(%)', 'Lymphocytes_(%)' : 'Lymphocytes(%)',
                          'Neutrophils_(%)' : 'Neutrophils(%)',
                          'Basophils_(%)' : 'Basophils(%)', 'Hematocrit' : 'HCT(%)', 'MCH' : 'MCH(pg)',
                          'Monocytes_(%)' : 'Monocytes(%)'}, inplace=True)

# %%
dfItaly.drop(columns = ['Neutrophils(%)'], inplace=True)

# %%
dfItaly = dfItaly.reindex(columns = dfBrazil.columns)

# %%
dfItaly
# Out:
#         HCT(%)  Haemoglobin(gms%)  Platelet Count(Lakh / Cumm)  \
# 0    -0.143897           0.034744                    -0.357794
# 1     0.601112           0.838773                     1.068793
# 2     0.361645           0.424576                    -0.363020
# 3     0.530159           0.643857                    -0.263734
# 4    -1.899991          -1.922540                    -1.874959
# ...        ...                ...                          ...
# 1383 -1.958274          -1.917899                     0.305856
# 1384 -1.758084          -1.597680                     0.483527
# 1385  0.873100           0.984961                    -0.324699
# 1386  1.966963           1.862084                    -0.049484
# 1387 -0.977598          -0.964202                    -0.279411
#
#       Lymphocytes(%)  MCHC(gms%)  Total WBC Count(/Cumm)  Basophils(%)  \
# 0          -0.470825    0.720550                0.276856      0.591746
# 1                NaN    1.055218                0.129722           NaN
# 2          -0.670739    0.385882               -0.395755     -0.883555
# 3           1.628280    0.608994                0.234818      2.067046
# 4           2.309807   -0.878421               -1.593844      0.591746
# ...              ...         ...                     ...           ...
# 1383       -0.531837   -0.570313                0.519777     -0.040526
# 1384        0.028962    0.162770               -0.582825     -0.514730
# 1385        0.510575    0.658574               -0.442698      1.452338
# 1386       -0.452650    0.162770                0.550104      0.222920
# 1387       -0.770697   -0.283455                0.108703     -0.145905
#
#        MCH(pg)  Eosinophils(%)  MCV(f L)  Monocytes(%)  Result
# 0     2.031963        1.245906  1.950285      0.429497       0
# 1    -0.243222             NaN -0.770177           NaN       1
# 2    -0.224572       -0.359497 -0.438237     -0.137165       0
# 3    -0.094029        0.504951 -0.394941      0.429497       0
# 4     0.937885        4.703700  1.601508      0.558283       0
# ...        ...             ...       ...           ...     ...
# 1383 -0.189939        1.625205  0.081320      0.124088       0
# 1384 -0.243222        0.813682 -0.337212     -0.162923       1
# 1385  1.472491        1.842787  1.351351      0.558283       1
# 1386  1.248703        0.134473  1.336918      0.017379       0
# 1387 -0.205923       -0.297751 -0.091866     -0.162923       0
#
# [1388 rows x 12 columns]

# %%
X_test = dfItaly.drop(columns = ['Result'])
Y_test = dfItaly['Result']

# %%
binary_predictions = internal_model.predict(X_test)
accuracy = accuracy_score(Y_test, binary_predictions)
print(f"Accuracy: {accuracy}")
print(classification_report(Y_test, binary_predictions))
cm = confusion_matrix(Y_test, binary_predictions)
sensitivity = cm[1,1]/(cm[1,0]+cm[1,1])
specificity = cm[0,0]/(cm[0,0]+cm[0,1])
balanced_accuracy = balanced_accuracy_score(Y_test, binary_predictions)
f2_score = fbeta_score(Y_test, binary_predictions, beta = 2)
print('sensitivity', sensitivity)
print('specificity', specificity)
print('balanced_accuracy', balanced_accuracy)
print('f2_score', f2_score)
roc_auc = roc_auc_score(Y_test, binary_predictions)
print('roc_auc_score', roc_auc_score(Y_test, binary_predictions))
y_proba = internal_model.predict_proba(X_test)[:, 1]
brier_score = brier_score_loss(Y_test, y_proba)
print('brierscore', brier_score_loss(Y_test, y_proba))
sns.heatmap(cm, annot = True, fmt = "d", cmap="Blues")
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

new_metrics = {
    'Model' : 'Brazil on Italy',
    'Sensitivity': sensitivity,
    'Specificity': specificity,
    'Accuracy' : accuracy,
    'Balanced Accuracy': balanced_accuracy,
    'F2 Score': f2_score,
    'ROC AUC': roc_auc,
    'Brier Score': brier_score
}

metrics_df.loc[len(metrics_df)] = new_metrics
display(metrics_df)
# Out:
# Accuracy: 0.6188760806916427
#               precision    recall  f1-score   support
#
#            0       0.55      0.86      0.67       623
#            1       0.79      0.42      0.55       765
#
#     accuracy                           0.62      1388
#    macro avg       0.67      0.64      0.61      1388
# weighted avg       0.68      0.62      0.60      1388
#
# sensitivity 0.42091503267973857
# specificity 0.8619582664526485
# balanced_accuracy 0.6414366495661935
# f2_score 0.46424452133794697
# roc_auc_score 0.6414366495661935
# brierscore 0.2605174121817328
#                    Model  Sensitivity  Specificity  Accuracy  \
# 0    Brazil on India 375     0.146667     0.846667  0.706667
# 0  Brazil on India Smote     0.176667     0.860000  0.518333
# 2        Brazil on Italy     0.420915     0.861958  0.618876
#
#    Balanced Accuracy  F2 Score   ROC AUC  Brier Score
# 0           0.496667  0.154062  0.496667     0.205045
# 0           0.518333  0.204633  0.518333     0.349804
# 2           0.641437  0.464245  0.641437     0.260517

# %%
computemetrics(Y_test, y_proba)
# Out:
# Threshold - 0.15 Standardized Net Benefit - 0.721 AUC Score - 0.746 Balanced Accuracy - 0.669
# Threshold - 0.5 Standardized Net Benefit - 0.308 AUC Score - 0.746 Balanced Accuracy - 0.641

# %%
sim_scoreBItaly = avgKS(X_test, dfBrazil)

# %%
out3 = pd.DataFrame()
out3['y_true'] = Y_test.copy()
out3['y_proba'] = ((internal_model.predict_proba(X_test))[:, 1])
out3.to_csv('../Results/1cItalyBrazil.csv', index = False)

# %%
metrics_df.to_csv('../Results/Brazil_metrics.csv', index = False)

# %%
br = pd.read_csv('../Results/Brazil_metrics.csv')
it = pd.read_csv('../Results/Italy_metrics.csv')

brit = pd.concat([br, it])

brit.to_csv('../Results/merged_brit.csv')
brit
# Out:
#                    Model  Sensitivity  Specificity  Accuracy  \
# 0    Brazil on India 375     0.146667     0.846667  0.706667
# 1  Brazil on India Smote     0.176667     0.860000  0.518333
# 2        Brazil on Italy     0.420915     0.861958  0.618876
# 0    Italy on Indian 375     0.440000     0.513333  0.498667
# 1    Italy on Indian 600     0.516667     0.570000  0.543333
# 2        Italy on Brazil     0.727186     0.620910  0.648959
#
#    Balanced Accuracy  F2 Score   ROC AUC  Brier Score
# 0           0.496667  0.154062  0.496667     0.205045
# 1           0.518333  0.204633  0.518333     0.349804
# 2           0.641437  0.464245  0.641437     0.260517
# 0           0.476667  0.344468  0.476667     0.363717
# 1           0.543333  0.522237  0.543333     0.334481
# 2           0.674048  0.628573  0.674048     0.274688

# %% [markdown]
# ## For EPD

# %%
df_similarity_Brazil = pd.DataFrame([sim_score375, sim_score600B, sim_scoreBItaly])

# %%
df_similarity_Brazil.to_csv('../Results/SimilarityBrazil.csv', index = False)

# %% [markdown]
# RUNNING SHAP

# %%
# ============ SHAP CELL 1 : imports and helpers ============
import os
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

OUT = '../SHAP_output'
os.makedirs(OUT, exist_ok = True)

def shap_for(model, X):
    """Return SHAP values and the frame they were computed on."""
    if hasattr(model, 'named_steps'):                  # India models are Pipelines
        X = X[list(map(str, model.feature_names_in_))]
        sel = model.named_steps['select']
        est = model.named_steps['model']
        cols = [c for c, k in zip(X.columns, sel.get_support()) if k]
        Xe = pd.DataFrame(sel.transform(X), columns = cols, index = X.index)
    else:                                              # Italy / Brazil are plain models
        est = model
        Xe = X[list(map(str, model.feature_names_in_))]
    sv = np.array(shap.TreeExplainer(est).shap_values(Xe))
    if sv.ndim == 3:
        sv = sv[:, :, 1]
    return sv, Xe

def report(tag, model, X):
    """Print the feature weight table and save CSV + 300 dpi figures."""
    sv, Xe = shap_for(model, X)
    t = pd.DataFrame({'feature': Xe.columns, 'mean_abs_shap': np.abs(sv).mean(0)})
    t = t.sort_values('mean_abs_shap', ascending = False).reset_index(drop = True)
    t['share_%'] = (t['mean_abs_shap'] / t['mean_abs_shap'].sum() * 100).round(1)
    print('\\n' + tag + '  (n = ' + str(len(Xe)) + ', ' + str(Xe.shape[1]) + ' features)')
    print(t.to_string(index = False))
    t.to_csv(OUT + '/shap_' + tag + '.csv', index = False)

    plt.figure()
    shap.summary_plot(sv, Xe, plot_type = 'bar', show = False, max_display = 14)
    plt.tight_layout(); plt.savefig(OUT + '/bar_' + tag + '.png', dpi = 300); plt.show()

    plt.figure()
    shap.summary_plot(sv, Xe, show = False, max_display = 14)
    plt.tight_layout(); plt.savefig(OUT + '/beeswarm_' + tag + '.png', dpi = 300); plt.show()
    return t

print('shap', shap.__version__, '| helpers ready')
# Out:
# shap 0.52.0 | helpers ready

# %%
# ============ SHAP CELL 2 : rebuild the Indian 375 test frame ============
# The other three test cohorts are still in memory from this notebook:
#   dfBrazil -> Brazilian cohort        (cell 13 to 17)
#   df       -> Indian SMOTE 600        (cell 36, already z-scored)
#   dfItaly  -> Italian cohort          (cell 43 to 47)
# Only the Indian 375 frame was overwritten, so it is rebuilt here.
# Same steps as cells 3 to 8, cell 10 and cell 27, unchanged.

df1_shap = pd.read_csv('../Data/Edited_bitsM.csv')
df2_shap = pd.read_csv('../Data/ESIdf.csv')
df1_shap = df1_shap[df1_shap['Result'] != 'Positive']       # only the 300 negatives
df_shap = pd.concat([df1_shap, df2_shap], join = 'inner')
df_shap = df_shap.drop(columns = [df_shap.columns[0], 'Others'])

encoder_shap = LabelEncoder()
df_shap['Result'] = encoder_shap.fit_transform(df_shap['Result'])
df_shap['Gender'] = encoder_shap.fit_transform(df_shap['Gender'])

# align to the Brazilian column set, same as cell 36 does
df_shap = df_shap.reindex(columns = dfBrazil.columns).copy()
cols_shap = df_shap.columns.tolist()
cols_shap.remove('Result')

# Standardizing the data (identical to cell 10)
for c in cols_shap:
    df_shap[c] = ((df_shap[c] - (df_shap[c].mean())))/(df_shap[c].std())

X_ind375 = df_shap.drop(columns = ['Result'])
print('Indian 375 frame rebuilt :', X_ind375.shape)
print('Indian 600 (df, in memory):', df.drop(columns = ['Result']).shape)
print('Brazilian (dfBrazil)      :', dfBrazil.drop(columns = ['Result']).shape)
print('Italian   (dfItaly)       :', dfItaly.drop(columns = ['Result']).shape)
# Out:
# Indian 375 frame rebuilt : (375, 11)
# Indian 600 (df, in memory): (600, 11)
# Brazilian (dfBrazil)      : (11916, 11)
# Italian   (dfItaly)       : (1388, 11)

# %%
# ============ SHAP CELL 3 : run SHAP on every cohort this model is tested on ============
# `internal_model` is the Brazil model, loaded in cell 25.
t_bra  = report('Brazil_on_Brazil',    internal_model, dfBrazil.drop(columns = ['Result']))
t_i375 = report('Brazil_on_India_375', internal_model, X_ind375)
t_i600 = report('Brazil_on_India_600', internal_model, df.drop(columns = ['Result']))
t_ita  = report('Brazil_on_Italy',     internal_model, dfItaly.drop(columns = ['Result']))
# Out:
# \nBrazil_on_Brazil  (n = 11916, 11 features)
#                     feature  mean_abs_shap  share_%
#      Total WBC Count(/Cumm)       0.628885     18.1
#                Basophils(%)       0.623501     18.0
#              Eosinophils(%)       0.414457     11.9
#              Lymphocytes(%)       0.382651     11.0
#                Monocytes(%)       0.290942      8.4
# Platelet Count(Lakh / Cumm)       0.260886      7.5
#                      HCT(%)       0.238622      6.9
#                    MCV(f L)       0.195495      5.6
#           Haemoglobin(gms%)       0.151053      4.4
#                  MCHC(gms%)       0.148685      4.3
#                     MCH(pg)       0.137154      3.9
# \nBrazil_on_India_375  (n = 375, 11 features)
#                     feature  mean_abs_shap  share_%
#      Total WBC Count(/Cumm)       0.682487     20.9
#              Lymphocytes(%)       0.439774     13.5
#              Eosinophils(%)       0.429229     13.2
#                Monocytes(%)       0.360159     11.0
#                Basophils(%)       0.322374      9.9
#                      HCT(%)       0.244017      7.5
# Platelet Count(Lakh / Cumm)       0.233785      7.2
#                    MCV(f L)       0.182258      5.6
#           Haemoglobin(gms%)       0.136811      4.2
#                     MCH(pg)       0.123872      3.8
#                  MCHC(gms%)       0.106820      3.3
# \nBrazil_on_India_600  (n = 600, 11 features)
#                     feature  mean_abs_shap  share_%
#      Total WBC Count(/Cumm)       0.781223     21.1
#              Eosinophils(%)       0.595388     16.1
#              Lymphocytes(%)       0.479253     12.9
#                Monocytes(%)       0.436442     11.8
#                Basophils(%)       0.340213      9.2
#                      HCT(%)       0.258058      7.0
# Platelet Count(Lakh / Cumm)       0.241401      6.5
#                    MCV(f L)       0.179503      4.8
#           Haemoglobin(gms%)       0.137409      3.7
#                     MCH(pg)       0.128268      3.5
#                  MCHC(gms%)       0.126582      3.4
# \nBrazil_on_Italy  (n = 1388, 11 features)
#                     feature  mean_abs_shap  share_%
#                Basophils(%)       0.618744     16.5
#      Total WBC Count(/Cumm)       0.605673     16.1
#              Lymphocytes(%)       0.515193     13.7
#              Eosinophils(%)       0.505702     13.5
#                Monocytes(%)       0.333760      8.9
#                      HCT(%)       0.286064      7.6
# Platelet Count(Lakh / Cumm)       0.250093      6.7
#                    MCV(f L)       0.200960      5.3
#           Haemoglobin(gms%)       0.156441      4.2
#                  MCHC(gms%)       0.145706      3.9
#                     MCH(pg)       0.139869      3.7

# %%
# ============ SHAP CELL 4 : comparison across cohorts ============
comp = pd.DataFrame({
    'Brazil_%':    t_bra.set_index('feature')['share_%'],
    'India375_%':  t_i375.set_index('feature')['share_%'],
    'India600_%':  t_i600.set_index('feature')['share_%'],
    'Italy_%':     t_ita.set_index('feature')['share_%'],
})
comp = comp.sort_values('Brazil_%', ascending = False)
comp.to_csv(OUT + '/brazil_model_all_cohorts.csv')
print('BRAZIL MODEL: share of total |SHAP| on each test cohort')
print(comp.to_string())
print()

shift = comp[['Brazil_%', 'India375_%']].copy()
shift['change'] = shift['India375_%'] - shift['Brazil_%']
shift = shift.sort_values('change', ascending = False)
shift.to_csv(OUT + '/brazil_transfer_shift.csv')
print('BRAZIL MODEL: Brazilian input vs Indian input')
print(shift.to_string())

ax = shift['change'].plot(kind = 'barh', figsize = (7, 5))
ax.axvline(0, color = 'black', lw = 0.8)
ax.set_xlabel('change in share of total |SHAP| (percentage points)')
ax.set_title('Brazil model: Brazilian input vs Indian input')
plt.tight_layout(); plt.savefig(OUT + '/brazil_transfer_shift.png', dpi = 300); plt.show()
# Out:
# BRAZIL MODEL: share of total |SHAP| on each test cohort
#                              Brazil_%  India375_%  India600_%  Italy_%
# feature
# Total WBC Count(/Cumm)           18.1        20.9        21.1     16.1
# Basophils(%)                     18.0         9.9         9.2     16.5
# Eosinophils(%)                   11.9        13.2        16.1     13.5
# Lymphocytes(%)                   11.0        13.5        12.9     13.7
# Monocytes(%)                      8.4        11.0        11.8      8.9
# Platelet Count(Lakh / Cumm)       7.5         7.2         6.5      6.7
# HCT(%)                            6.9         7.5         7.0      7.6
# MCV(f L)                          5.6         5.6         4.8      5.3
# Haemoglobin(gms%)                 4.4         4.2         3.7      4.2
# MCHC(gms%)                        4.3         3.3         3.4      3.9
# MCH(pg)                           3.9         3.8         3.5      3.7
#
# BRAZIL MODEL: Brazilian input vs Indian input
#                              Brazil_%  India375_%    change
# feature
# Total WBC Count(/Cumm)           18.1        20.9  2.799999
# Monocytes(%)                      8.4        11.0  2.600000
# Lymphocytes(%)                   11.0        13.5  2.500000
# Eosinophils(%)                   11.9        13.2  1.300000
# HCT(%)                            6.9         7.5  0.600000
# MCV(f L)                          5.6         5.6  0.000000
# MCH(pg)                           3.9         3.8 -0.100000
# Haemoglobin(gms%)                 4.4         4.2 -0.200000
# Platelet Count(Lakh / Cumm)       7.5         7.2 -0.300000
# MCHC(gms%)                        4.3         3.3 -1.000000
# Basophils(%)                     18.0         9.9 -8.100000
